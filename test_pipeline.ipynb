# %%
from traffic_accident import TrafficAccidentPipeline
# %matplotlib inline

# %%
pipe = TrafficAccidentPipeline()

# %%
pipe.load_model_data()

# %%
pipe.build_model()

# %%
data = pipe.get_live_data()

# %%
#pipe.get_current_result()

# %%
pipe.plot_current_result()

# %%
pipe.close()

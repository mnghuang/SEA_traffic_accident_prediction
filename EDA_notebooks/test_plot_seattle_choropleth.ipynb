# %%
import pandas as pd
import numpy as np
import psycopg2
from plot_seattle_choropleth import PlotSeattleChoropleth
# %matplotlib inline

# %%
query = 'select * from zone_latlong'
conn = psycopg2.connect(dbname='traffic_accident', user='minghuang', host='localhost')
df = pd.read_sql_query(query, con=conn)
df['values'] = np.random.random(len(df.zone_beat))
df = df.drop(['latitude', 'longitude'], axis=1)

# %%
psc = PlotSeattleChoropleth('data/Precincts/WGS84_3/geo_yutr-ryap-1', 'Name')

# %%
psc.fit_data(df)

# %%
psc.plot_map(title_name='Traffic Accident Probabilities in Seattle Precincts')

# %%
np.random.random(10)
# Out:
# array([ 0.75152385,  0.90258939,  0.95497167,  0.26228302,  0.09097313,
#         0.8319977 ,  0.04442339,  0.36552074,  0.11683558,  0.71599373])

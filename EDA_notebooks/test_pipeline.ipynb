# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import imp
# %matplotlib inline

mod = imp.load_source('TrafficAccidentPipeline', '../main_scripts/traffic_accident.py')

# %%
pipe = mod.TrafficAccidentPipeline()

# %%
pipe.load_model_data(limit=1000000)

# %%
pipe.build_model(pickle_path=None)

# %%
pipe.plot_current_result()

# %%
pipe.close()

# %%
#pipe.psc.df_map

# %%
#df, districts = pipe.get_live_data()

# %%
result = pipe.get_current_result()
result[1]
# Out:
# [0.059999999999999998,
#  0.029999999999999999,
#  0.059999999999999998,
#  0.059999999999999998,
#  0.029999999999999999,
#  0.029999999999999999,
#  0.11,
#  0.11,
#  0.040000000000000001,
#  0.059999999999999998,
#  0.10000000000000001,
#  0.11,
#  0.12,
#  0.059999999999999998,
#  0.070000000000000007,
#  0.089999999999999997,
#  0.040000000000000001,
#  0.040000000000000001,
#  0.050000000000000003,
#  0.080000000000000002,
#  0.059999999999999998,
#  0.040000000000000001,
#  0.02,
#  0.080000000000000002,
#  0.059999999999999998,
#  0.089999999999999997,
#  0.059999999999999998,
#  0.040000000000000001,
#  0.040000000000000001,
#  0.029999999999999999,
#  0.080000000000000002,
#  0.070000000000000007,
#  0.089999999999999997,
#  0.059999999999999998,
#  0.080000000000000002,
#  0.12,
#  0.059999999999999998,
#  0.070000000000000007,
#  0.029999999999999999,
#  0.10000000000000001,
#  0.10000000000000001,
#  0.059999999999999998,
#  0.059999999999999998,
#  0.050000000000000003,
#  0.050000000000000003,
#  0.070000000000000007,
#  0.11,
#  0.10000000000000001,
#  0.070000000000000007,
#  0.040000000000000001,
#  0.050000000000000003]

# %%
#pipe.model.bins

# %%
import cPickle as pickle

# %%
with open('../main_scripts/website/data/model.pkl', 'rb') as f:
    model = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-21-591442954a66> in <module>()
#       1 with open('../main_scripts/website/data/model.pkl', 'rb') as f:
# ----> 2     model = pickle.load(f)
#
# EOFError:

# %%
pwd
# Out:
# u'/Users/minghuang/Documents/git/SEA_traffic_accident_prediction/EDA_notebooks'
